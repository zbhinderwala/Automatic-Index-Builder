# %%
import pandas as pd
import numpy as np

# %%
index_properties = pd.read_csv("Merge_properties.csv", low_memory=False)

# %%
index_properties['pos_rank'] = 2
index_properties.loc[index_properties.pos == 'NN' , 'pos_rank'] = 14
index_properties.loc[index_properties.pos == 'JJ' , 'pos_rank' ] = 7
index_properties.loc[index_properties.pos == 'NNS' , 'pos_rank'] = 6
index_properties.loc[index_properties.pos == 'NNP' , 'pos_rank' ] = 6
index_properties.loc[index_properties.pos == 'VBP' , 'pos_rank' ] = 3

# %%
index_properties.head()
# Out:
#        word  n_gram_score  pos  frequency    tf_idf       inf  source  \
# 0      free             2   JJ        100  0.090967 -0.018507       1
# 1    matrix             2   NN         64  0.058219 -0.014049       1
# 2   unitary             2   JJ         42  0.038206 -0.010586       1
# 3   follows             2  VBZ         40  0.036387 -0.010232       1
# 4  circular             2   JJ         38  0.034568 -0.009871       1
#
#    pos_rank
# 0         7
# 1        14
# 2         7
# 3         2
# 4         7

# %%
index_properties['score'] = 0
for index,row in index_properties.iterrows():
    score = ((row['pos_rank'] * row['n_gram_score']) + row['inf'])*row['tf_idf'] 
    index_properties.loc[index , 'score'] = score

# %%
index_properties.head()
# Out:
#        word  n_gram_score  pos  frequency    tf_idf       inf  source  \
# 0      free             2   JJ        100  0.090967 -0.018507       1
# 1    matrix             2   NN         64  0.058219 -0.014049       1
# 2   unitary             2   JJ         42  0.038206 -0.010586       1
# 3   follows             2  VBZ         40  0.036387 -0.010232       1
# 4  circular             2   JJ         38  0.034568 -0.009871       1
#
#    pos_rank     score
# 0         7  1.271861
# 1        14  1.629319
# 2         7  0.534484
# 3         2  0.145176
# 4         7  0.483606

# %%
index_properties = index_properties.sort_values(['score'], ascending=False)
index_properties['word'] = index_properties['word'].str.lower()
index_properties = index_properties.drop_duplicates(['word'],keep='first')

# %%
index_properties_1 = index_properties.loc[index_properties.source == 1]
index_properties_2 = index_properties.loc[index_properties.source == 2]
index_properties_3 = index_properties.loc[index_properties.source == 3]
index_properties_4 = index_properties.loc[index_properties.source == 4]

# %%
indexes = pd.read_csv("Indexes_Updated.csv", low_memory=False)

# %%
indexes_1 = indexes.loc[indexes.source == 1]
indexes_2 = indexes.loc[indexes.source == 2]
indexes_3 = indexes.loc[indexes.source == 3]
indexes_4 = indexes.loc[indexes.source == 4]

# %%
indexes_4.shape
# Out:
# (48, 4)

# %%
index_properties_1[:50]
# Out:
#                          word  n_gram_score  pos  frequency    tf_idf  \
# 41              matrix convex            10   NN         14  0.012735
# 40         free spectrahedron            10   NN         14  0.012735
# 9               free circular            10   JJ         27  0.024561
# 51        unitary conjugation            10   NN         13  0.011826
# 1                      matrix             2   NN         64  0.058219
# 61              linear pencil            10   NN         11  0.010006
# 78        unitary equivalence            10   NN         10  0.009097
# 0                        free             2   JJ        100  0.090967
# 81        block decomposition            10   NN          9  0.008187
# 107                direct sum            10   NN          7  0.006368
# 6                      pencil             2   NN         33  0.030019
# 46         coordinate unitary            10   JJ         13  0.011826
# 35                cross terms            10  NNS         15  0.013645
# 140               pencil ball            10   NN          6  0.005458
# 127           circular matrix            10   NN          6  0.005458
# 8                      convex             2   NN         27  0.024561
# 53                convex sets            10  NNS         12  0.010916
# 54         matrix polynomials            10  NNS         12  0.010916
# 178        separation theorem            10   NN          5  0.004548
# 182               unit vector            10   NN          5  0.004548
# 176         reducing subspace            10   NN          5  0.004548
# 186               zero column            10   NN          5  0.004548
# 77       unitarily equivalent            10   JJ         10  0.009097
# 14                        j=1             2   NN         23  0.020923
# 15                     denote             2   NN         22  0.020013
# 66                direct sums            10  NNS         10  0.009097
# 72          positive integers            10  NNS         10  0.009097
# 20                   subspace             2   NN         21  0.019103
# 2                     unitary             2   JJ         42  0.038206
# 210         commutative cross            10   NN          4  0.003639
# 242          positive integer            10   NN          4  0.003639
# 241         orthonormal basis            10   NN          4  0.003639
# 208             circular free            10   NN          4  0.003639
# 207                block zero            10   NN          4  0.003639
# 97          matrix polynomial            10   JJ          8  0.007277
# 23              spectrahedron             2   NN         20  0.018193
# 4                    circular             2   JJ         38  0.034568
# 25                      block             2   NN         18  0.016374
# 27                   operator             2   NN         18  0.016374
# 26                      cross             2   NN         18  0.016374
# 28                conjugation             2   NN         17  0.015464
# 32                    respect             2   NN         16  0.014555
# 5                    matrices             2  NNS         37  0.033658
# 345                prove item            10   NN          3  0.002729
# 339  orthogonal decomposition            10   NN          3  0.002729
# 338           operator pencil            10   NN          3  0.002729
# 331                monic free            10   NN          3  0.002729
# 297           defining pencil            10   NN          3  0.002729
# 314        homogeneous linear            10   NN          3  0.002729
# 308               free matrix            10   NN          3  0.002729
#
#           inf  source  pos_rank     score
# 41  -0.004716       1        14  1.782902
# 40  -0.004716       1        14  1.782902
# 9   -0.007726       1         7  1.719095
# 51  -0.004453       1        14  1.655555
# 1   -0.014049       1        14  1.629319
# 61  -0.003910       1        14  1.400860
# 78  -0.003628       1        14  1.273512
# 0   -0.018507       1         7  1.271861
# 81  -0.003339       1        14  1.146163
# 107 -0.002733       1        14  0.891464
# 6   -0.008932       1        14  0.840271
# 46  -0.004453       1         7  0.827751
# 35  -0.004973       1         6  0.818639
# 140 -0.002414       1        14  0.764114
# 127 -0.002414       1        14  0.764114
# 8   -0.007726       1        14  0.687524
# 53  -0.004185       1         6  0.654920
# 54  -0.004185       1         6  0.654920
# 178 -0.002082       1        14  0.636763
# 182 -0.002082       1        14  0.636763
# 176 -0.002082       1        14  0.636763
# 186 -0.002082       1        14  0.636763
# 77  -0.003628       1         7  0.636739
# 14  -0.006866       1        14  0.585687
# 15  -0.006643       1        14  0.560227
# 66  -0.003628       1         6  0.545772
# 72  -0.003628       1         6  0.545772
# 20  -0.006416       1        14  0.534766
# 2   -0.010586       1         7  0.534484
# 210 -0.001734       1        14  0.509411
# 242 -0.001734       1        14  0.509411
# 241 -0.001734       1        14  0.509411
# 208 -0.001734       1        14  0.509411
# 207 -0.001734       1        14  0.509411
# 97  -0.003040       1         7  0.509396
# 23  -0.006186       1        14  0.509305
# 4   -0.009871       1         7  0.483606
# 25  -0.005714       1        14  0.458382
# 27  -0.005714       1        14  0.458382
# 26  -0.005714       1        14  0.458382
# 28  -0.005472       1        14  0.432921
# 32  -0.005225       1        14  0.407458
# 5   -0.009687       1         6  0.403569
# 345 -0.001367       1        14  0.382060
# 339 -0.001367       1        14  0.382060
# 338 -0.001367       1        14  0.382060
# 331 -0.001367       1        14  0.382060
# 297 -0.001367       1        14  0.382060
# 314 -0.001367       1        14  0.382060
# 308 -0.001367       1        14  0.382060

# %%
def match_count(predicted, actual):
    count = 0
    pred_copy = predicted
    act_copy = actual
    for str in predicted:
        if (actual.count(str) >= 1):
            count = count + 1
            act_copy.remove(str)
            pred_copy.remove(str)
    left_pred = pred_copy
    left_act = act_copy
    match = False
    for str in pred_copy:
            for index in act_copy:
                if(index.find(str) != -1):
                    count = count + 1
                    act_copy.remove(index)
                    match = True
            if match:
                pred_copy.remove(str)
    list = [count, len(pred_copy),len(act_copy)]
    return list

# %%
res_idx_1 = match_count(list(index_properties_1['word'][:24].values), list(indexes_1['word'].values))

# %%
res_idx_1
# Out:
# [10, 11, 13]

# %%
res_idx_2 = match_count(list(index_properties_2['word'][:500].values), list(indexes_2['word'].values))
res_idx_2
# Out:
# [260, 243, 288]

# %%
res_idx_3 = match_count(list(index_properties_3['word'][:500].values), list(indexes_3['word'].values))
res_idx_3
# Out:
# [309, 248, 135]

# %%
res_idx_4 = match_count(list(index_properties_4['word'][:60].values), list(indexes_4['word'].values))
res_idx_4
# Out:
# [16, 27, 32]

# %%
def find_precision_recall(result):
    tp = result[0]
    fp = result[1]
    fn = result[2]
    
    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    evaluation = [precision,recall]
    return evaluation

# %%
eval1 = find_precision_recall(res_idx_1)
eval2 = find_precision_recall(res_idx_2)
eval3 = find_precision_recall(res_idx_3)
eval4 = find_precision_recall(res_idx_4)
print( eval1 , eval2 , eval3 , eval4)
# Out:
# [0.47619047619047616, 0.43478260869565216] [0.5168986083499006, 0.4744525547445255] [0.5547576301615799, 0.6959459459459459] [0.37209302325581395, 0.3333333333333333]

# %%
avg_precision = (eval1[0]+eval2[0]+eval3[0]+eval4[0])/4
avg_recall = (eval1[1]+eval2[1]+eval3[1]+eval4[1])/4
print( avg_precision, avg_recall)
# Out:
# 0.4799849344894426 0.48462861067986424
